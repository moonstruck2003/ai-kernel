# %% [markdown]
# #### How to split by character-Character Text Splitter
# This is the simplest method. This splits based on a given character sequence, which defaults to "\n\n". Chunk length is measured by number of characters.
#
# 1. How the text is split: by single character separator.
# 2. How the chunk size is measured: by number of characters.

# %%
from langchain_community.document_loaders import TextLoader 

loader = TextLoader("speech.txt")
docs=loader.load()
docs
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_15652\1703560853.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# [Document(metadata={'source': 'speech.txt'}, page_content='"Ahem. Testing, 1, 2, 3—is this stream active? Good. Welcome, data engineers, to the annual convention of misplaced semicolons and runaway JSON payloads on August 15, 2026. Today, we are looking at 5,421 distinct microservices running on a cluster located at 45.33.19.128 port 8080. If the packet loss exceeds 14.5%, or if user @db_admin_99 shouts \'NullPointerException\' into an open microphone, the Kafka topic logs-prod-v2 will pivot into a dead-letter queue.Let me quote our chief architect, Dr. Jane Doe: \'In theory, theory and practice are the same; in practice, they are a distributed systems nightmare with missing schema registries.\' We utilize Apache Kafka, Snowflake, and sometimes a tired PostgreSQL instance that hasn\'t seen a vacuum process since Tuesday. Remember: garbage in means a very expensive cloud bill out. Thank you, and please do not drop the production table before lunch."')]

# %%
from langchain_text_splitters import CharacterTextSplitter 

text_splitter = CharacterTextSplitter(separator="\n\n",chunk_size=60,chunk_overlap=10)
text_splitter.split_documents(docs)
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='"Ahem. Testing, 1, 2, 3—is this stream active? Good. Welcome, data engineers, to the annual convention of misplaced semicolons and runaway JSON payloads on August 15, 2026. Today, we are looking at 5,421 distinct microservices running on a cluster located at 45.33.19.128 port 8080. If the packet loss exceeds 14.5%, or if user @db_admin_99 shouts \'NullPointerException\' into an open microphone, the Kafka topic logs-prod-v2 will pivot into a dead-letter queue.Let me quote our chief architect, Dr. Jane Doe: \'In theory, theory and practice are the same; in practice, they are a distributed systems nightmare with missing schema registries.\' We utilize Apache Kafka, Snowflake, and sometimes a tired PostgreSQL instance that hasn\'t seen a vacuum process since Tuesday. Remember: garbage in means a very expensive cloud bill out. Thank you, and please do not drop the production table before lunch."')]

# %%
speech=""
with open("speech.txt") as f:
    speech=f.read()


text_splitter=CharacterTextSplitter(chunk_size=100,chunk_overlap=20)
text=text_splitter.create_documents([speech])
print(text[0])
# Out:
# page_content='"Ahem. Testing, 1, 2, 3—is this stream active? Good. Welcome, data engineers, to the annual convention of misplaced semicolons and runaway JSON payloads on August 15, 2026. Today, we are looking at 5,421 distinct microservices running on a cluster located at 45.33.19.128 port 8080. If the packet loss exceeds 14.5%, or if user @db_admin_99 shouts 'NullPointerException' into an open microphone, the Kafka topic logs-prod-v2 will pivot into a dead-letter queue.Let me quote our chief architect, Dr. Jane Doe: 'In theory, theory and practice are the same; in practice, they are a distributed systems nightmare with missing schema registries.' We utilize Apache Kafka, Snowflake, and sometimes a tired PostgreSQL instance that hasn't seen a vacuum process since Tuesday. Remember: garbage in means a very expensive cloud bill out. Thank you, and please do not drop the production table before lunch."'
