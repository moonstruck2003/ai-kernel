# %%
# %pip install gensim
from gensim.models import Word2Vec, KeyedVectors
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\Mridul\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip
# Collecting gensim
#   Downloading gensim-4.4.0-cp311-cp311-win_amd64.whl.metadata (8.6 kB)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\mridul\appdata\local\programs\python\python311\lib\site-packages (from gensim) (2.1.3)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\mridul\appdata\local\programs\python\python311\lib\site-packages (from gensim) (1.15.3)
# Collecting smart_open>=1.8.1 (from gensim)
#   Using cached smart_open-7.6.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: wrapt in c:\users\mridul\appdata\local\programs\python\python311\lib\site-packages (from smart_open>=1.8.1->gensim) (1.17.2)
# Downloading gensim-4.4.0-cp311-cp311-win_amd64.whl (24.4 MB)
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#    ---------------------------------------- 0.3/24.4 MB ? eta -:--:--
#    - -------------------------------------- 0.8/24.4 MB 3.1 MB/s eta 0:00:08
#    --- ------------------------------------ 2.4/24.4 MB 5.0 MB/s eta 0:00:05
#    ----- ---------------------------------- 3.1/24.4 MB 4.9 MB/s eta 0:00:05
#    ------- -------------------------------- 4.5/24.4 MB 5.0 MB/s eta 0:00:05
#    -------- ------------------------------- 5.2/24.4 MB 4.9 MB/s eta 0:00:04
#    ---------- ----------------------------- 6.3/24.4 MB 5.0 MB/s eta 0:00:04
#    ------------ --------------------------- 7.3/24.4 MB 4.9 MB/s eta 0:00:04
#    ------------- -------------------------- 8.4/24.4 MB 5.0 MB/s eta 0:00:04
#    --------------- ------------------------ 9.4/24.4 MB 5.0 MB/s eta 0:00:04
#    ----------------- ---------------------- 10.5/24.4 MB 5.0 MB/s eta 0:00:03
#    ------------------ --------------------- 11.5/24.4 MB 5.0 MB/s eta 0:00:03
#    -------------------- ------------------- 12.6/24.4 MB 5.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 13.9/24.4 MB 5.1 MB/s eta 0:00:03
#    ------------------------ --------------- 14.7/24.4 MB 5.1 MB/s eta 0:00:02
#    ------------------------- -------------- 15.7/24.4 MB 5.0 MB/s eta 0:00:02
#    --------------------------- ------------ 16.5/24.4 MB 4.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 17.3/24.4 MB 4.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 18.1/24.4 MB 4.8 MB/s eta 0:00:02
#    ------------------------------ --------- 18.9/24.4 MB 4.7 MB/s eta 0:00:02
#    -------------------------------- ------- 19.7/24.4 MB 4.7 MB/s eta 0:00:02
#    --------------------------------- ------ 20.4/24.4 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 21.0/24.4 MB 4.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 21.8/24.4 MB 4.6 MB/s eta 0:00:01
#    ------------------------------------ --- 22.5/24.4 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 23.1/24.4 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  23.9/24.4 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  24.4/24.4 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 24.4/24.4 MB 4.3 MB/s eta 0:00:00
# Using cached smart_open-7.6.1-py3-none-any.whl (64 kB)
# Installing collected packages: smart_open, gensim
#
#    ---------------------------------------- 0/2 [smart_open]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    ---------------------------------------- 2/2 [gensim]
#
# Successfully installed gensim-4.4.0 smart_open-7.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
import gensim.downloader as api

# %%
wv = api.load('word2vec-google-news-300')

vec_ing = wv['king']
