# %% [markdown]
# #### Getting started With Langchain And Open AI
#
# In this quickstart we'll see how to:
#
# - Get setup with LangChain, LangSmith and LangServe
# - Use the most basic and common components of LangChain: prompt templates, models, and output parsers.
# - Build a simple application with LangChain
# - Trace your application with LangSmith
# - Serve your application with LangServe

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
## langsmith tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGHCAIN_TRACING_V2"]="true"
os.environ["LANGHCAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_groq import ChatGroq

llm=ChatGroq(
    model="openai/gpt-oss-20b" 
)

# %%
print(llm)
# Out:
# metadata={'lc_versions': {'langchain-core': '1.6.2', 'langchain': '1.4.0'}} profile={'name': 'GPT OSS 20B', 'release_date': '2025-08-05', 'last_updated': '2026-05-27', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': False, 'temperature': True} client=<groq.resources.chat.completions.Completions object at 0x0000020F60F4CB90> async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000020F60F4D590> model_name='openai/gpt-oss-20b' model_kwargs={} groq_api_key=SecretStr('**********')

# %%
response = llm.invoke("What is Agentic AI?")
print(response.content)
# Out:
# ## Agentic AI – a quick guide
#
# | **Aspect** | **What it means** |
# |------------|--------------------|
# | **Core idea** | AI that can *act with purpose*—it has goals, plans, and can decide how to achieve them, rather than just following pre‑written rules or reacting to inputs. |
# | **Agency** | The system behaves as if it has an *inner “will”*—it can set its own objectives, evaluate alternatives, and choose a course of action. |
# | **Autonomy** | It operates independently of direct human instruction once the task is defined. |
# | **Learning** | It can adapt its strategies based on experience, improving over time. |
# | **Goal‑directed behavior** | It can balance multiple objectives, trade‑offs, and long‑term planning. |
#
# ---
#
# ## How Agentic AI differs from other AI types
#
# | **Type** | **Typical behavior** | **Agency?** |
# |----------|----------------------|-------------|
# | **Rule‑based / symbolic AI** | Executes fixed procedures; no learning. | **No** – no self‑generated goals. |
# | **Statistical / machine‑learning models** | Predicts or classifies based on data. | **No** – no internal goal‑setting. |
# | **Reinforcement learning agents** | Learns a policy to maximize reward. | **Yes** – but usually *reward‑driven* rather than *goal‑oriented* (unless the reward is a proxy for a goal). |
# | **Agentic AI** | Sets its own sub‑goals, plans, and can re‑prioritize. | **Yes** – true self‑directed behavior. |
#
# ---
#
# ## Key components that give an AI “agency”
#
# 1. **Goal representation** – The AI can encode what it wants to achieve (e.g., “deliver a package safely”).
# 2. **Planning & reasoning** – It can generate a sequence of actions to reach the goal, often using search, logic, or probabilistic planning.
# 3. **Decision‑making** – It evaluates alternatives and selects the best one, sometimes under uncertainty.
# 4. **Learning & adaptation** – It updates its model of the world or its own capabilities based on experience.
# 5. **Self‑monitoring** – It can assess progress toward its goal and adjust if necessary.
#
# ---
#
# ## Examples of Agentic AI
#
# | **Domain** | **Example** | **Why it’s agentic** |
# |------------|-------------|----------------------|
# | Autonomous vehicles | Self‑driving cars that decide routes, speed, and obstacle avoidance. | They set “reach destination safely” as a goal and plan in real time. |
# | Robotics | Household robots that clean, cook, or deliver items. | They plan tasks, manage resources, and adapt to changing environments. |
# | Personal assistants | AI that schedules meetings, sends reminders, and learns user preferences. | It sets “maximize user productivity” as a goal and chooses actions accordingly. |
# | Game AI | Non‑player characters that pursue strategic objectives. | They plan and adapt to player behavior to achieve victory. |
#
# ---
#
# ## Why “agentic” matters
#
# 1. **Scalability** – Agents can handle complex, dynamic environments without constant human oversight.
# 2. **Efficiency** – They can optimize for multiple criteria (speed, cost, safety) simultaneously.
# 3. **Human‑like interaction** – They can negotiate, explain, and collaborate with humans more naturally.
# 4. **Ethical and safety concerns** – With autonomy comes the risk of unintended actions or misaligned goals.
#    *Key issues*: value alignment, explainability, control mechanisms, and accountability.
#
# ---
#
# ## A quick technical sketch
#
# ```python
# class Agent:
#     def __init__(self, goal):
#         self.goal = goal          # e.g., "deliver package"
#         self.plan = None
#
#     def observe(self, world_state):
#         # Update internal model
#         self.world = world_state
#
#     def plan(self):
#         # Generate a sequence of actions to achieve self.goal
#         self.plan = search(self.world, self.goal)
#
#     def act(self):
#         if not self.plan:
#             self.plan()
#         action = self.plan.pop(0)
#         execute(action)
#
#     def learn(self, outcome):
#         # Update model based on success/failure
#         self.world.update(outcome)
# ```
#
# *This skeleton shows the loop of perception → planning → action → learning that gives the agent its agency.*
#
# ---
#
# ## Take‑away
#
# **Agentic AI** is AI that behaves like a *self‑directed agent*: it sets its own goals, plans how to reach them, acts autonomously, and learns from experience. It sits at the intersection of planning, learning, and decision‑making, enabling machines to operate independently in complex, real‑world settings—while also demanding careful oversight to keep their goals aligned with human values.
